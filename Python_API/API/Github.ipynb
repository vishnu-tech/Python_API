# %%
#import libraries

import json
import requests

# %%
#https://github.com/wishkaushik

username = 'wishkaushik'
url = 'https://api.github.com/users/{}'.format(username)

# %%
url
# Out:
# 'https://api.github.com/users/wishkaushik'

# %%
response = requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
print(response.text)
# Out:
# {"login":"wishkaushik","id":19621751,"node_id":"MDQ6VXNlcjE5NjIxNzUx","avatar_url":"https://avatars.githubusercontent.com/u/19621751?v=4","gravatar_id":"","url":"https://api.github.com/users/wishkaushik","html_url":"https://github.com/wishkaushik","followers_url":"https://api.github.com/users/wishkaushik/followers","following_url":"https://api.github.com/users/wishkaushik/following{/other_user}","gists_url":"https://api.github.com/users/wishkaushik/gists{/gist_id}","starred_url":"https://api.github.com/users/wishkaushik/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/wishkaushik/subscriptions","organizations_url":"https://api.github.com/users/wishkaushik/orgs","repos_url":"https://api.github.com/users/wishkaushik/repos","events_url":"https://api.github.com/users/wishkaushik/events{/privacy}","received_events_url":"https://api.github.com/users/wishkaushik/received_events","type":"User","site_admin":false,"name":"Atulya Kaushik","company":"PrepInsta","blog":"","location":null,"email":null,"hireable":null,"bio":"Founder PrepInsta","twitter_username":null,"public_repos":0,"public_gists":0,"followers":1,"following":0,"created_at":"2016-05-28T09:53:08Z","updated_at":"2022-09-08T18:26:42Z"}

# %%
type(response.text)
# Out:
# str

# %%
output = response.json()

# %%
type(output)
# Out:
# dict

# %%
output
# Out:
# {'login': 'wishkaushik',
#  'id': 19621751,
#  'node_id': 'MDQ6VXNlcjE5NjIxNzUx',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/19621751?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/wishkaushik',
#  'html_url': 'https://github.com/wishkaushik',
#  'followers_url': 'https://api.github.com/users/wishkaushik/followers',
#  'following_url': 'https://api.github.com/users/wishkaushik/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/wishkaushik/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/wishkaushik/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/wishkaushik/subscriptions',
#  'organizations_url': 'https://api.github.com/users/wishkaushik/orgs',
#  'repos_url': 'https://api.github.com/users/wishkaushik/repos',
#  'events_url': 'https://api.github.com/users/wishkaushik/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/wishkaushik/received_events',
#  'type': 'User',
#  'site_admin': False,
#  'name': 'Atulya Kaushik',
#  'company': 'PrepInsta',
#  'blog': '',
#  'location': None,
#  'email': None,
#  'hireable': None,
#  'bio': 'Founder PrepInsta',
#  'twitter_username': None,
#  'public_repos': 0,
#  'public_gists': 0,
#  'followers': 1,
#  'following': 0,
#  'created_at': '2016-05-28T09:53:08Z',
#  'updated_at': '2022-09-08T18:26:42Z'}

# %%
output['avatar_url']
# Out:
# 'https://avatars.githubusercontent.com/u/19621751?v=4'

# %%
response_img = requests.get(output['avatar_url'])

foo = open('{}_img.png'.format(username),'wb')
foo.write(response_img.content)
foo.close()

# %%
! pip install sckit-image
# Out:
# ERROR: Could not find a version that satisfies the requirement sckit-image (from versions: none)
# ERROR: No matching distribution found for sckit-image
# WARNING: You are using pip version 22.0.3; however, version 22.3 is available.
# You should consider upgrading via the '/opt/miniconda3/bin/python -m pip install --upgrade pip' command.

# %%
 ! pip install scikit-image
# Out:
# Requirement already satisfied: scikit-image in /opt/miniconda3/lib/python3.8/site-packages (0.19.3)
# Requirement already satisfied: imageio>=2.4.1 in /opt/miniconda3/lib/python3.8/site-packages (from scikit-image) (2.22.2)
# Requirement already satisfied: PyWavelets>=1.1.1 in /opt/miniconda3/lib/python3.8/site-packages (from scikit-image) (1.3.0)
# Requirement already satisfied: packaging>=20.0 in /opt/miniconda3/lib/python3.8/site-packages (from scikit-image) (21.3)
# Requirement already satisfied: scipy>=1.4.1 in /opt/miniconda3/lib/python3.8/site-packages (from scikit-image) (1.7.3)
# Requirement already satisfied: networkx>=2.2 in /opt/miniconda3/lib/python3.8/site-packages (from scikit-image) (2.6.3)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /opt/miniconda3/lib/python3.8/site-packages (from scikit-image) (8.3.2)
# Requirement already satisfied: tifffile>=2019.7.26 in /opt/miniconda3/lib/python3.8/site-packages (from scikit-image) (2022.10.10)
# Requirement already satisfied: numpy>=1.17.0 in /opt/miniconda3/lib/python3.8/site-packages (from scikit-image) (1.21.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/miniconda3/lib/python3.8/site-packages (from packaging>=20.0->scikit-image) (2.4.7)
# WARNING: You are using pip version 22.0.3; however, version 22.3 is available.
# You should consider upgrading via the '/opt/miniconda3/bin/python -m pip install --upgrade pip' command.

# %%
from skimage import io

img_url = output['avatar_url']

img = io.imread(img_url)

io.imshow(img)
